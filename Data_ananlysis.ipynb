# %%
import numpy as np

# %% [markdown]
# ### Optimizer Test for n = 5, 10 & l = 1

# %%
ll = np.load("newHamTest510_optimizercomparison.npy")

data5 = dict()
for i in range(2):
    for l in range(1):
        for o in range(6):
            for g in range(4):
                name = "n"+ str(i) +"l" + str(l+1) + "O" + str(o) + "G" + str(g)
                data5[name] = ll[i][l][o][g]

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

fig, ax = plt.subplots(2,3)
fig.set_size_inches(18.5, 10.5) 
fig.suptitle("n=5")

x = data5['n0l1O0G0']
x1 = data5['n0l1O0G1']
x2 = data5['n0l1O0G2']
x3 =data5['n0l1O0G3']

ax[0][0].set_title("l1")
ax[0][0].hist([x[:,0], x1[:,0], x2[:,0], x3[:,0]], 65, label=["Grad0", "Grad1", "Grad2", "Grad3"])
ax[0][0].legend()

a = data5['n0l1O1G0']
a1 = data5['n0l1O1G1']
a2 = data5['n0l1O1G2']
a3 =data5['n0l1O1G3']

ax[0][1].set_title("l2")
ax[0][1].hist([a[:,0], a1[:,0], a2[:,0], a3[:,0]], 65, label=["Grad0", "Grad1", "Grad2", "Grad3"])
ax[0][1].legend()

b = data5['n0l1O2G0']
b1 = data5['n0l1O2G1']
b2 = data5['n0l1O2G2']
b3 =data5['n0l1O2G3']

ax[0][2].set_title("l3")
ax[0][2].hist([b[:,0], b1[:,0], b2[:,0], b3[:,0]], 65, label=["Grad0", "Grad1", "Grad2", "Grad3"])
ax[0][2].legend()

c = data5['n0l1O3G0']
c1 = data5['n0l1O3G1']
c2 = data5['n0l1O3G2']
c3 =data5['n0l1O3G3']

ax[1][0].set_title("l4")
ax[1][0].hist([c[:,0], c1[:,0], c2[:,0], c3[:,0]], 65, label=["Grad0", "Grad1", "Grad2", "Grad3"])
ax[1][0].legend()

d = data5['n0l1O4G0']
d1 = data5['n0l1O4G1']
d2 = data5['n0l1O4G2']
d3 =data5['n0l1O4G3']

ax[1][1].set_title("GSLS")
ax[1][1].hist([d[:,0], d1[:,0], d2[:,0], d3[:,0]], 65, label=["Grad0", "Grad1", "Grad2", "Grad3"])
ax[1][1].legend()

e = data5['n0l1O5G0']
e1 = data5['n0l1O5G1']
e2 = data5['n0l1O5G2']
e3 =data5['n0l1O5G3']

ax[1][2].set_title("NELDER_MEAD")
ax[1][2].hist([e[:,0], e1[:,0], e2[:,0], e3[:,0]], 65, label=["Grad0", "Grad1", "Grad2", "Grad3"])
ax[1][2].legend()
plt.show()

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

fig, ax = plt.subplots(2,3)
fig.set_size_inches(18.5, 10.5) 
fig.suptitle("n=10")

x = data5['n1l1O0G0']
x1 = data5['n1l1O0G1']
x2 = data5['n1l1O0G2']
x3 =data5['n1l1O0G3']

ax[0][0].set_title("l1")
ax[0][0].hist([x[:,0], x1[:,0], x2[:,0], x3[:,0]], 65, label=["Grad0", "Grad1", "Grad2", "Grad3"])
ax[0][0].legend()

a = data5['n1l1O1G0']
a1 = data5['n1l1O1G1']
a2 = data5['n1l1O1G2']
a3 =data5['n1l1O1G3']

ax[0][1].set_title("l2")
ax[0][1].hist([a[:,0], a1[:,0], a2[:,0], a3[:,0]], 65, label=["Grad0", "Grad1", "Grad2", "Grad3"])
ax[0][1].legend()

b = data5['n1l1O2G0']
b1 = data5['n1l1O2G1']
b2 = data5['n1l1O2G2']
b3 =data5['n1l1O2G3']

ax[0][2].set_title("l3")
ax[0][2].hist([b[:,0], b1[:,0], b2[:,0], b3[:,0]], 65, label=["Grad0", "Grad1", "Grad2", "Grad3"])
ax[0][2].legend()

c = data5['n1l1O3G0']
c1 = data5['n1l1O3G1']
c2 = data5['n1l1O3G2']
c3 =data5['n1l1O3G3']

ax[1][0].set_title("l4")
ax[1][0].hist([c[:,0], c1[:,0], c2[:,0], c3[:,0]], 65, label=["Grad0", "Grad1", "Grad2", "Grad3"])
ax[1][0].legend()

d = data5['n1l1O4G0']
d1 = data5['n1l1O4G1']
d2 = data5['n1l1O4G2']
d3 =data5['n1l1O4G3']

ax[1][1].set_title("GSLS")
ax[1][1].hist([d[:,0], d1[:,0], d2[:,0], d3[:,0]], 65, label=["Grad0", "Grad1", "Grad2", "Grad3"])
ax[1][1].legend()

e = data5['n1l1O5G0']
e1 = data5['n1l1O5G1']
e2 = data5['n1l1O5G2']
e3 =data5['n1l1O5G3']

ax[1][2].set_title("NELDER_MEAD")
ax[1][2].hist([e[:,0], e1[:,0], e2[:,0], e3[:,0]], 65, label=["Grad0", "Grad1", "Grad2", "Grad3"])
ax[1][2].legend()
plt.show()

# %% [markdown]
# ### Prime Test n= 5,7,11

# %%
ll = np.load("newHamTest5711.npy")

data5 = dict()
for i in range(3):
    for l in range(4):
        for o in range(1):
            for g in range(4):
                name = "n"+ str(i) +"l" + str(l+1) + "O" + str(o) + "G" + str(g)
                data5[name] = ll[i][l][o][g]

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

fig, ax = plt.subplots(2,3)
fig.set_size_inches(18.5, 10.5) 
fig.suptitle("n=5")

x = data5['n0l1O0G0']
x1 = data5['n0l1O0G1']
x2 = data5['n0l1O0G2']
x3 =data5['n0l1O0G3']

ax[0][0].set_title("l1")
ax[0][0].hist([x[:,0], x1[:,0], x2[:,0], x3[:,0]], 65, label=["Grad0", "Grad1", "Grad2", "Grad3"])
ax[0][0].legend()

a = data5['n0l2O0G0']
a1 = data5['n0l2O0G1']
a2 = data5['n0l2O0G2']
a3 =data5['n0l2O0G3']

ax[0][1].set_title("l2")
ax[0][1].hist([a[:,0], a1[:,0], a2[:,0], a3[:,0]], 65, label=["Grad0", "Grad1", "Grad2", "Grad3"])
ax[0][1].legend()

b = data5['n0l3O0G0']
b1 = data5['n0l3O0G1']
b2 = data5['n0l3O0G2']
b3 =data5['n0l3O0G3']

ax[0][2].set_title("l3")
ax[0][2].hist([b[:,0], b1[:,0], b2[:,0], b3[:,0]], 65, label=["Grad0", "Grad1", "Grad2", "Grad3"])
ax[0][2].legend()

c = data5['n0l4O0G0']
c1 = data5['n0l4O0G1']
c2 = data5['n0l4O0G2']
c3 =data5['n0l4O0G3']

ax[1][0].set_title("l4")
ax[1][0].hist([c[:,0], c1[:,0], c2[:,0], c3[:,0]], 65, label=["Grad0", "Grad1", "Grad2", "Grad3"])
ax[1][0].legend()

# d = data5['l1O4G0']
# d1 = data5['l1O4G1']
# d2 = data5['l1O4G2']
# d3 =data5['l1O4G3']

# ax[1][1].set_title("GSLS")
# ax[1][1].hist([d[:,0], d1[:,0], d2[:,0], d3[:,0]], 65, label=["Grad0", "Grad1", "Grad2", "Grad3"])
# ax[1][1].legend()

# e = data5['l1O5G0']
# e1 = data5['l1O5G1']
# e2 = data5['l1O5G2']
# e3 =data5['l1O5G3']

# ax[1][2].set_title("NELDER_MEAD")
# ax[1][2].hist([e[:,0], e1[:,0], e2[:,0], e3[:,0]], 65, label=["Grad0", "Grad1", "Grad2", "Grad3"])
# ax[1][2].legend()
plt.show()

# %%
fig, ax = plt.subplots(2,3)
fig.set_size_inches(18.5, 10.5) 
fig.suptitle("n=7")

x = data5['n1l1O0G0']
x1 = data5['n1l1O0G1']
x2 = data5['n1l1O0G2']
x3 =data5['n1l1O0G3']

ax[0][0].set_title("l1")
ax[0][0].hist([x[:,0], x1[:,0], x2[:,0], x3[:,0]], 65, label=["Grad0", "Grad1", "Grad2", "Grad3"])
ax[0][0].legend()

a = data5['n1l2O0G0']
a1 = data5['n1l2O0G1']
a2 = data5['n1l2O0G2']
a3 =data5['n1l2O0G3']

ax[0][1].set_title("l2")
ax[0][1].hist([a[:,0], a1[:,0], a2[:,0], a3[:,0]], 65, label=["Grad0", "Grad1", "Grad2", "Grad3"])
ax[0][1].legend()

b = data5['n1l3O0G0']
b1 = data5['n1l3O0G1']
b2 = data5['n1l3O0G2']
b3 =data5['n1l3O0G3']

ax[0][2].set_title("l3")
ax[0][2].hist([b[:,0], b1[:,0], b2[:,0], b3[:,0]], 65, label=["Grad0", "Grad1", "Grad2", "Grad3"])
ax[0][2].legend()

c = data5['n1l4O0G0']
c1 = data5['n1l4O0G1']
c2 = data5['n1l4O0G2']
c3 =data5['n1l4O0G3']

ax[1][0].set_title("l4")
ax[1][0].hist([c[:,0], c1[:,0], c2[:,0], c3[:,0]], 65, label=["Grad0", "Grad1", "Grad2", "Grad3"])
ax[1][0].legend()

# d = data5['l1O4G0']
# d1 = data5['l1O4G1']
# d2 = data5['l1O4G2']
# d3 =data5['l1O4G3']

# ax[1][1].set_title("GSLS")
# ax[1][1].hist([d[:,0], d1[:,0], d2[:,0], d3[:,0]], 65, label=["Grad0", "Grad1", "Grad2", "Grad3"])
# ax[1][1].legend()

# e = data5['l1O5G0']
# e1 = data5['l1O5G1']
# e2 = data5['l1O5G2']
# e3 =data5['l1O5G3']

# ax[1][2].set_title("NELDER_MEAD")
# ax[1][2].hist([e[:,0], e1[:,0], e2[:,0], e3[:,0]], 65, label=["Grad0", "Grad1", "Grad2", "Grad3"])
# ax[1][2].legend()
plt.show()

# %%
fig, ax = plt.subplots(2,3)
fig.set_size_inches(18.5, 10.5) 
fig.suptitle("n=11")

x = data5['n2l1O0G0']
x1 = data5['n2l1O0G1']
x2 = data5['n2l1O0G2']
x3 =data5['n2l1O0G3']

ax[0][0].set_title("l1")
ax[0][0].hist([x[:,0], x1[:,0], x2[:,0], x3[:,0]], 65, label=["Grad0", "Grad1", "Grad2", "Grad3"])
ax[0][0].legend()

a = data5['n2l2O0G0']
a1 = data5['n2l2O0G1']
a2 = data5['n2l2O0G2']
a3 =data5['n2l2O0G3']

ax[0][1].set_title("l2")
ax[0][1].hist([a[:,0], a1[:,0], a2[:,0], a3[:,0]], 65, label=["Grad0", "Grad1", "Grad2", "Grad3"])
ax[0][1].legend()

b = data5['n2l3O0G0']
b1 = data5['n2l3O0G1']
b2 = data5['n2l3O0G2']
b3 =data5['n2l3O0G3']

ax[0][2].set_title("l3")
ax[0][2].hist([b[:,0], b1[:,0], b2[:,0], b3[:,0]], 65, label=["Grad0", "Grad1", "Grad2", "Grad3"])
ax[0][2].legend()

c = data5['n2l4O0G0']
c1 = data5['n2l4O0G1']
c2 = data5['n2l4O0G2']
c3 =data5['n2l4O0G3']

ax[1][0].set_title("l4")
ax[1][0].hist([c[:,0], c1[:,0], c2[:,0], c3[:,0]], 65, label=["Grad0", "Grad1", "Grad2", "Grad3"])
ax[1][0].legend()

# d = data5['l1O4G0']
# d1 = data5['l1O4G1']
# d2 = data5['l1O4G2']
# d3 =data5['l1O4G3']

# ax[1][1].set_title("GSLS")
# ax[1][1].hist([d[:,0], d1[:,0], d2[:,0], d3[:,0]], 65, label=["Grad0", "Grad1", "Grad2", "Grad3"])
# ax[1][1].legend()

# e = data5['l1O5G0']
# e1 = data5['l1O5G1']
# e2 = data5['l1O5G2']
# e3 =data5['l1O5G3']

# ax[1][2].set_title("NELDER_MEAD")
# ax[1][2].hist([e[:,0], e1[:,0], e2[:,0], e3[:,0]], 65, label=["Grad0", "Grad1", "Grad2", "Grad3"])
# ax[1][2].legend()
plt.show()

# %% [markdown]
# ### Squared Test n = 5

# %%
ll = np.load("newHamTest5square.npy")

data5 = dict()
for i in range(1):
    for l in range(4):
        for o in range(1):
            for g in range(4):
                name = "n"+ str(i) +"l" + str(l+1) + "O" + str(o) + "G" + str(g)
                data5[name] = ll[i][l][o][g]

# %%
fig, ax = plt.subplots(2,3)
fig.set_size_inches(18.5, 10.5)
fig.suptitle("n=5 r^2")

x = data5['n0l1O0G0']
x1 = data5['n0l1O0G1']
x2 = data5['n0l1O0G2']
x3 =data5['n0l1O0G3']

ax[0][0].set_title("1 Layer")
ax[0][0].hist([x[:,0], x1[:,0], x2[:,0], x3[:,0]], 65, label=["Grad0", "Grad1", "Grad2", "Grad3"])
ax[0][0].legend()

a = data5['n0l2O0G0']
a1 = data5['n0l2O0G1']
a2 = data5['n0l2O0G2']
a3 =data5['n0l2O0G3']

ax[0][1].set_title("2 Layer")
ax[0][1].hist([a[:,0], a1[:,0], a2[:,0], a3[:,0]], 65, label=["Grad0", "Grad1", "Grad2", "Grad3"])
ax[0][1].legend()

b = data5['n0l3O0G0']
b1 = data5['n0l3O0G1']
b2 = data5['n0l3O0G2']
b3 =data5['n0l3O0G3']

ax[0][2].set_title("3 Layer")
ax[0][2].hist([b[:,0], b1[:,0], b2[:,0], b3[:,0]], 65, label=["Grad0", "Grad1", "Grad2", "Grad3"])
ax[0][2].legend()

c = data5['n0l4O0G0']
c1 = data5['n0l4O0G1']
c2 = data5['n0l4O0G2']
c3 =data5['n0l4O0G3']

ax[1][0].set_title("4 Layer")
ax[1][0].hist([c[:,0], c1[:,0], c2[:,0], c3[:,0]], 65, label=["Grad0", "Grad1", "Grad2", "Grad3"])
ax[1][0].legend()

# d = data5['l4O4G0']
# d1 = data5['l4O4G1']
# d2 = data5['l4O4G2']
# d3 =data5['l4O4G3']

# ax[1][1].set_title("GSLS")
# ax[1][1].hist([d[:,0], d1[:,0], d2[:,0], d3[:,0]], 65, label=["Grad0", "Grad1", "Grad2", "Grad3"])
# ax[1][1].legend()

# e = data5['l4O5G0']
# e1 = data5['l4O5G1']
# e2 = data5['l4O5G2']
# e3 =data5['l4O5G3']

# ax[1][2].set_title("NELDER_MEAD")
# ax[1][2].hist([e[:,0], e1[:,0], e2[:,0], e3[:,0]], 65, label=["Grad0", "Grad1", "Grad2", "Grad3"])
# ax[1][2].legend()
plt.show()

# %% [markdown]
# ### Range 2, 15 , L = 1, O = AQGD

# %%
ll = np.load("newHamTestrange15square.npy")

data5 = dict()
for i in range(14):
    for l in range(1):
        for o in range(1):
            for g in range(1):
                name = "n"+ str(i) +"l" + str(l+1) + "O" + str(o) + "G" + str(g)
                data5[name] = ll[i][l][o][g]

# %%
fig, ax = plt.subplots(3,5)
fig.set_size_inches(18.5, 10.5)
fig.suptitle("n=range(2,15) r^2")

x2 = data5['n0l1O0G0']
ax[0][0].set_title("n=2")
ax[0][0].hist(x2[:,0], 100, label=["Grad0"])
ax[0][0].legend()
x3 = data5['n1l1O0G0']
ax[0][1].set_title("n=3")
ax[0][1].hist(x3[:,0], 100, label=["Grad0"])
ax[0][1].legend()
x4 = data5['n2l1O0G0']
ax[0][2].set_title("n=4")
ax[0][2].hist(x4[:,0], 100, label=["Grad0"])
ax[0][2].legend()
x5 = data5['n3l1O0G0']
ax[0][3].set_title("n=5")
ax[0][3].hist(x5[:,0], 100, label=["Grad0"])
ax[0][3].legend()
x6 = data5['n4l1O0G0']
ax[0][4].set_title("n=6")
ax[0][4].hist(x6[:,0], 100, label=["Grad0"])
ax[0][4].legend()
x7 = data5['n5l1O0G0']
ax[1][0].set_title("n=7")
ax[1][0].hist(x7[:,0], 100, label=["Grad0"])
ax[1][0].legend()
x8 = data5['n6l1O0G0']
ax[1][1].set_title("n=8")
ax[1][1].hist(x8[:,0], 100, label=["Grad0"])
ax[1][1].legend()
x9 = data5['n7l1O0G0']
ax[1][2].set_title("n=9")
ax[1][2].hist(x9[:,0], 100, label=["Grad0"])
ax[1][2].legend()
x10 = data5['n8l1O0G0']
ax[1][3].set_title("n=10")
ax[1][3].hist(x10[:,0], 100, label=["Grad0"])
ax[1][3].legend()
x11 = data5['n9l1O0G0']
ax[1][4].set_title("n=11")
ax[1][4].hist(x11[:,0], 100, label=["Grad0"])
ax[1][4].legend()
x12 = data5['n10l1O0G0']
ax[2][0].set_title("n=12")
ax[2][0].hist(x12[:,0], 100, label=["Grad0"])
ax[2][0].legend()
x13 = data5['n11l1O0G0']
ax[2][1].set_title("n=13")
ax[2][1].hist(x13[:,0], 100, label=["Grad0"])
ax[2][1].legend()
x14 = data5['n12l1O0G0']
ax[2][2].set_title("n=14")
ax[2][2].hist(x14[:,0], 100, label=["Grad0"])
ax[2][2].legend()
x15 = data5['n13l1O0G0']
ax[2][3].set_title("n=15")
ax[2][3].hist(x15[:,0], 100, label=["Grad0"])
ax[2][3].legend()

plt.show()

# %%
ll = np.load("newHamTestrange15.npy")

data5 = dict()
for i in range(14):
    for l in range(1):
        for o in range(1):
            for g in range(1):
                name = "n"+ str(i) +"l" + str(l+1) + "O" + str(o) + "G" + str(g)
                data5[name] = ll[i][l][o][g]

# %%
fig, ax = plt.subplots(3,5)
fig.set_size_inches(18.5, 10.5)
fig.suptitle("n=range(2,15) r")

x2 = data5['n0l1O0G0']
ax[0][0].set_title("n=2")
ax[0][0].hist(x2[:,0], 100, label=["Grad0"])
ax[0][0].legend()
x3 = data5['n1l1O0G0']
ax[0][1].set_title("n=3")
ax[0][1].hist(x3[:,0], 100, label=["Grad0"])
ax[0][1].legend()
x4 = data5['n2l1O0G0']
ax[0][2].set_title("n=4")
ax[0][2].hist(x4[:,0], 100, label=["Grad0"])
ax[0][2].legend()
x5 = data5['n3l1O0G0']
ax[0][3].set_title("n=5")
ax[0][3].hist(x5[:,0], 100, label=["Grad0"])
ax[0][3].legend()
x6 = data5['n4l1O0G0']
ax[0][4].set_title("n=6")
ax[0][4].hist(x6[:,0], 100, label=["Grad0"])
ax[0][4].legend()
x7 = data5['n5l1O0G0']
ax[1][0].set_title("n=7")
ax[1][0].hist(x7[:,0], 100, label=["Grad0"])
ax[1][0].legend()
x8 = data5['n6l1O0G0']
ax[1][1].set_title("n=8")
ax[1][1].hist(x8[:,0], 100, label=["Grad0"])
ax[1][1].legend()
x9 = data5['n7l1O0G0']
ax[1][2].set_title("n=9")
ax[1][2].hist(x9[:,0], 100, label=["Grad0"])
ax[1][2].legend()
x10 = data5['n8l1O0G0']
ax[1][3].set_title("n=10")
ax[1][3].hist(x10[:,0], 100, label=["Grad0"])
ax[1][3].legend()
x11 = data5['n9l1O0G0']
ax[1][4].set_title("n=11")
ax[1][4].hist(x11[:,0], 100, label=["Grad0"])
ax[1][4].legend()
x12 = data5['n10l1O0G0']
ax[2][0].set_title("n=12")
ax[2][0].hist(x12[:,0], 100, label=["Grad0"])
ax[2][0].legend()
x13 = data5['n11l1O0G0']
ax[2][1].set_title("n=13")
ax[2][1].hist(x13[:,0], 100, label=["Grad0"])
ax[2][1].legend()
x14 = data5['n12l1O0G0']
ax[2][2].set_title("n=14")
ax[2][2].hist(x14[:,0], 100, label=["Grad0"])
ax[2][2].legend()
x15 = data5['n13l1O0G0']
ax[2][3].set_title("n=15")
ax[2][3].hist(x15[:,0], 100, label=["Grad0"])
ax[2][3].legend()

plt.show()

# %%
ll = np.load("newHamTestrange15param.npy")

data5 = dict()
for i in range(14):
    for l in range(1):
        for o in range(1):
            for g in range(1):
                name = "n"+ str(i) +"l" + str(l+1) + "O" + str(o) + "G" + str(g)
                data5[name] = ll[i][l][o][g]

# %%
fig, ax = plt.subplots(3,5)
fig.set_size_inches(18.5, 10.5)
fig.suptitle("n=range(2,15) r")

x2 = data5['n0l1O0G0']
ax[0][0].set_title("n=2")
ax[0][0].hist(x2[:,0], 100, label=["Grad0"])
ax[0][0].legend()
x3 = data5['n1l1O0G0']
ax[0][1].set_title("n=3")
ax[0][1].hist(x3[:,0], 100, label=["Grad0"])
ax[0][1].legend()
x4 = data5['n2l1O0G0']
ax[0][2].set_title("n=4")
ax[0][2].hist(x4[:,0], 100, label=["Grad0"])
ax[0][2].legend()
x5 = data5['n3l1O0G0']
ax[0][3].set_title("n=5")
ax[0][3].hist(x5[:,0], 100, label=["Grad0"])
ax[0][3].legend()
x6 = data5['n4l1O0G0']
ax[0][4].set_title("n=6")
ax[0][4].hist(x6[:,0], 100, label=["Grad0"])
ax[0][4].legend()
x7 = data5['n5l1O0G0']
ax[1][0].set_title("n=7")
ax[1][0].hist(x7[:,0], 100, label=["Grad0"])
ax[1][0].legend()
x8 = data5['n6l1O0G0']
ax[1][1].set_title("n=8")
ax[1][1].hist(x8[:,0], 100, label=["Grad0"])
ax[1][1].legend()
x9 = data5['n7l1O0G0']
ax[1][2].set_title("n=9")
ax[1][2].hist(x9[:,0], 100, label=["Grad0"])
ax[1][2].legend()
x10 = data5['n8l1O0G0']
ax[1][3].set_title("n=10")
ax[1][3].hist(x10[:,0], 100, label=["Grad0"])
ax[1][3].legend()
x11 = data5['n9l1O0G0']
ax[1][4].set_title("n=11")
ax[1][4].hist(x11[:,0], 100, label=["Grad0"])
ax[1][4].legend()
x12 = data5['n10l1O0G0']
ax[2][0].set_title("n=12")
ax[2][0].hist(x12[:,0], 100, label=["Grad0"])
ax[2][0].legend()
x13 = data5['n11l1O0G0']
ax[2][1].set_title("n=13")
ax[2][1].hist(x13[:,0], 100, label=["Grad0"])
ax[2][1].legend()
x14 = data5['n12l1O0G0']
ax[2][2].set_title("n=14")
ax[2][2].hist(x14[:,0], 100, label=["Grad0"])
ax[2][2].legend()
x15 = data5['n13l1O0G0']
ax[2][3].set_title("n=15")
ax[2][3].hist(x15[:,0], 100, label=["Grad0"])
ax[2][3].legend()

plt.show()
